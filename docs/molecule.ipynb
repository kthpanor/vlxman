# %% [markdown]
# # Molecule

# %% [markdown]
# A detailed list of keyword can be found in the [molecule section](./keywords.ipynb#molecule) of the [Input file keywords page](./keywords.ipynb). There is different ways to create a molecule object such as using a smile string, an xyz string or a xyz input files.
#
# **Python script**

# %%
import veloxchem as vlx

xyz_str = """
3

O    0.0000000    0.0000000   -0.1653507
H    0.7493682    0.0000000    0.4424329
H   -0.7493682    0.0000000    0.4424329
"""

h2o = vlx.Molecule.read_xyz_string(xyz_str)
aspirin = vlx.Molecule.read_smiles('CC(=O)OC1=CC=CC=C1C(=O)O')
tq = vlx.Molecule.read_xyz_file('../input_files/tq-polymer.xyz')

h2o.show(atom_indices=True, atom_labels=True)
aspirin.show(atom_indices=True)
tq.show()
# Out:
# <div id="3dmolviewer_1747314076644862"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_1747314076644862" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_1747314076644862 = null;
# var warn = document.getElementById("3dmolwarning_1747314076644862");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1747314076644862 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1747314076644862"),{backgroundColor:"white"});
# viewer_1747314076644862.zoomTo();
# 	viewer_1747314076644862.addModel("3\n\nO              0.000000000000         0.000000000000        -0.165350700000\nH              0.749368200000         0.000000000000         0.442432900000\nH             -0.749368200000         0.000000000000         0.442432900000\n");
# 	viewer_1747314076644862.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_1747314076644862.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_1747314076644862.addLabel("O1",{"position": {"x": 0.0, "y": 0.0, "z": -0.1653507}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1747314076644862.addLabel("H2",{"position": {"x": 0.7493682, "y": 0.0, "z": 0.4424329}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1747314076644862.addLabel("H3",{"position": {"x": -0.7493682, "y": 0.0, "z": 0.4424329}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1747314076644862.zoomTo();
# viewer_1747314076644862.render();
# });
# </script>
# <div id="3dmolviewer_17473140766482458"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17473140766482458" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17473140766482458 = null;
# var warn = document.getElementById("3dmolwarning_17473140766482458");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17473140766482458 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17473140766482458"),{backgroundColor:"white"});
# viewer_17473140766482458.zoomTo();
# 	viewer_17473140766482458.addModel("21\n\nC             -0.484318000000        -1.811956000000        -2.027082000000\nC              0.254396000000        -1.193455000000        -0.889631000000\nO              1.513798000000        -1.248447000000        -0.864273000000\nO             -0.456880000000        -0.466819000000         0.073917000000\nC              0.055284000000        -0.036207000000         1.308906000000\nC              1.025313000000        -0.795835000000         1.992278000000\nC              1.520970000000        -0.371312000000         3.225171000000\nC              1.050172000000         0.807718000000         3.798280000000\nC              0.075069000000         1.563160000000         3.145343000000\nC             -0.439739000000         1.153374000000         1.900263000000\nC             -1.478133000000         1.987584000000         1.240732000000\nO             -1.947973000000         1.669760000000         0.115204000000\nO             -1.946834000000         3.141269000000         1.864878000000\nH             -0.525064000000        -1.096339000000        -2.874290000000\nH              0.027353000000        -2.741293000000        -2.355331000000\nH             -1.518674000000        -2.064457000000        -1.712872000000\nH              1.379814000000        -1.734391000000         1.588623000000\nH              2.265585000000        -0.963259000000         3.741727000000\nH              1.435584000000         1.133899000000         4.755759000000\nH             -0.275971000000         2.470963000000         3.619611000000\nH             -2.653964000000         3.719717000000         1.427047000000\n");
# 	viewer_17473140766482458.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17473140766482458.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17473140766482458.addLabel("1",{"position": {"x": -0.484318, "y": -1.811956, "z": -2.027082}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("2",{"position": {"x": 0.254396, "y": -1.193455, "z": -0.8896309999999998}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("3",{"position": {"x": 1.5137979999999998, "y": -1.248447, "z": -0.864273}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("4",{"position": {"x": -0.45688, "y": -0.46681899999999993, "z": 0.073917}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("5",{"position": {"x": 0.055284, "y": -0.036207, "z": 1.3089059999999997}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("6",{"position": {"x": 1.025313, "y": -0.795835, "z": 1.9922779999999998}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("7",{"position": {"x": 1.5209699999999997, "y": -0.371312, "z": 3.225171}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("8",{"position": {"x": 1.050172, "y": 0.807718, "z": 3.79828}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("9",{"position": {"x": 0.07506899999999998, "y": 1.5631599999999999, "z": 3.145343}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("10",{"position": {"x": -0.439739, "y": 1.153374, "z": 1.9002629999999998}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("11",{"position": {"x": -1.4781329999999997, "y": 1.987584, "z": 1.240732}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("12",{"position": {"x": -1.947973, "y": 1.66976, "z": 0.115204}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("13",{"position": {"x": -1.946834, "y": 3.141269, "z": 1.864878}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("14",{"position": {"x": -0.525064, "y": -1.096339, "z": -2.87429}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("15",{"position": {"x": 0.027353, "y": -2.741293, "z": -2.355331}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("16",{"position": {"x": -1.518674, "y": -2.064457, "z": -1.712872}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("17",{"position": {"x": 1.3798139999999999, "y": -1.7343909999999998, "z": 1.588623}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("18",{"position": {"x": 2.265585, "y": -0.963259, "z": 3.7417269999999996}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("19",{"position": {"x": 1.4355839999999997, "y": 1.133899, "z": 4.755759}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("20",{"position": {"x": -0.275971, "y": 2.470963, "z": 3.619611}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.addLabel("21",{"position": {"x": -2.653964, "y": 3.719717, "z": 1.4270469999999997}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473140766482458.zoomTo();
# viewer_17473140766482458.render();
# });
# </script>
# <div id="3dmolviewer_17473140766582196"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17473140766582196" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17473140766582196 = null;
# var warn = document.getElementById("3dmolwarning_17473140766582196");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17473140766582196 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17473140766582196"),{backgroundColor:"white"});
# viewer_17473140766582196.zoomTo();
# 	viewer_17473140766582196.addModel("394\n\nC             -1.691130000000        -0.246710000000        -0.588720000000\nC             -0.300540000000        -0.217850000000        -0.702250000000\nC              0.451510000000        -1.406400000000        -0.849300000000\nC             -0.260710000000        -2.641130000000        -0.881920000000\nC             -1.662440000000        -2.649910000000        -0.760600000000\nC             -2.371490000000        -1.459020000000        -0.614140000000\nH             -2.243140000000         0.676950000000        -0.473800000000\nH              0.179940000000         0.750150000000        -0.668570000000\nH              2.694380000000        -3.351080000000        -1.097950000000\nC              1.947280000000        -1.291120000000        -0.940650000000\nC              2.904940000000        -2.302560000000        -1.043270000000\nC              4.231890000000        -1.845710000000        -1.053780000000\nC              4.363850000000        -0.456970000000        -0.972230000000\nS              2.800570000000         0.161980000000        -0.891360000000\nN              0.365720000000        -3.834000000000        -1.045200000000\nC             -0.285520000000        -5.034000000000        -1.088830000000\nC             -1.704820000000        -5.035080000000        -0.899600000000\nN             -2.325450000000        -3.830660000000        -0.765520000000\nH              5.058430000000        -2.537570000000        -1.119580000000\nH              4.011760000000         6.450630000000        -0.225670000000\nC              0.552510000000        -6.224440000000        -1.437040000000\nC              1.908010000000        -6.260420000000        -1.054910000000\nC              2.737530000000        -7.343660000000        -1.410860000000\nC              2.201810000000        -8.392890000000        -2.163000000000\nC              0.867560000000        -8.363380000000        -2.566440000000\nC              0.050770000000        -7.287400000000        -2.215730000000\nH              0.466770000000        -9.172400000000        -3.163620000000\nC             -2.579870000000        -6.243260000000        -0.742020000000\nC             -2.100650000000        -7.460250000000        -0.214380000000\nC             -2.952790000000        -8.552370000000        -0.045130000000\nC             -4.301550000000        -8.451910000000        -0.381420000000\nC             -4.815840000000        -7.242470000000        -0.883940000000\nC             -3.953520000000        -6.150390000000        -1.051840000000\nH             -1.072550000000        -7.573570000000         0.094710000000\nH              2.826470000000        -9.230640000000        -2.446670000000\nO              4.047910000000        -7.408930000000        -1.057250000000\nC              4.740430000000        -6.448010000000        -0.349070000000\nH             -0.967900000000        -7.283730000000        -2.576940000000\nH             -4.936690000000        -9.315210000000        -0.235370000000\nH             -3.450340000000        -1.471710000000        -0.517180000000\nH             -4.364480000000        -5.224920000000        -1.436830000000\nH             -2.566430000000        -9.479310000000         0.359180000000\nO             -6.125260000000        -7.086030000000        -1.211430000000\nC             -7.104710000000        -8.051110000000        -1.095790000000\nH              4.738700000000        -5.485780000000        -0.905200000000\nH              4.286990000000        -6.309080000000         0.655350000000\nH             -6.856900000000        -8.928250000000        -1.730860000000\nH             -7.210440000000        -8.365600000000        -0.035410000000\nC              6.863810000000        -0.360140000000        -0.791950000000\nC              8.077230000000         0.319220000000        -0.729170000000\nC              8.144440000000         1.722540000000        -0.802300000000\nC              6.922510000000  ...

# %% [markdown]
# Conformation of the molecule can be altered using the ```set_dihedral_in_degrees``` function as explained in the next cell.

# %%
h2o2 = vlx.Molecule.read_smiles('OO')
h2o2.set_dihedral_in_degrees([3,1,2,4],180.0)
h2o2.show(atom_indices=True)
# Out:
# <div id="3dmolviewer_17473142850764637"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17473142850764637" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17473142850764637 = null;
# var warn = document.getElementById("3dmolwarning_17473142850764637");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17473142850764637 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17473142850764637"),{backgroundColor:"white"});
# viewer_17473142850764637.zoomTo();
# 	viewer_17473142850764637.addModel("4\n\nO              2.045467000000        -0.774747000000         1.060144000000\nO              1.994263000000         0.532849000000         0.911917000000\nH              1.291706000000        -0.990544000000         1.666890000000\nH              2.748023708423         0.748644663972         0.305171414165\n");
# 	viewer_17473142850764637.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17473142850764637.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17473142850764637.addLabel("1",{"position": {"x": 2.045467, "y": -0.774747, "z": 1.0601439999999998}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473142850764637.addLabel("2",{"position": {"x": 1.9942629999999997, "y": 0.532849, "z": 0.911917}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473142850764637.addLabel("3",{"position": {"x": 1.291706, "y": -0.990544, "z": 1.66689}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473142850764637.addLabel("4",{"position": {"x": 2.748023708422624, "y": 0.7486446639715176, "z": 0.30517141416495225}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473142850764637.zoomTo();
# viewer_17473142850764637.render();
# });
# </script>

# %% [markdown]
# The charge and multiplicity of a molecule can be adjusted using the  ```set_charge ``` and  ```set_multiplicity ``` functions. In the example below, we create a molecule object for the phenyl radical cation.

# %%
phenyl= vlx.Molecule.read_smiles('c1ccccc1')
phenyl.set_charge(1)
phenyl.set_multiplicity(2)

# %% [markdown]
# **Text file**

# %% [markdown]
# In Veloxchem text input file, charge and multiplicity are specified, the geometry can either be specified with ```xyz``` or ```xyz_file```.
#
# ```
# @molecule
# charge: 0
# multiplicity: 1
# xyz:
# O    0.0000000    0.0000000   -0.1653507
# H    0.7493682    0.0000000    0.4424329
# H   -0.7493682    0.0000000    0.4424329
# @end
# ```
#
# ```
# @molecule
# charge: 0
# multiplicity: 1
# xyz_file: '../input_files/tq-polymer.xyz'
# ```
